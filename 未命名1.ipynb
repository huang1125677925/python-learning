# %%
#encoding=utf-8
# %matplotlib inline
import matplotlib.pyplot as plt
 
# 121 > 1行2列第1个
fig1 = plt.subplot(121)
plt.pie([1,2,3])
# 122 > 1行2列第2个
fig2 = plt.subplot(122)
plt.title('抖音使用现状分析')
plt.pie([10,5,5])
# Out:
# ([<matplotlib.patches.Wedge at 0x117eb8c18>,
#   <matplotlib.patches.Wedge at 0x117eca160>,
#   <matplotlib.patches.Wedge at 0x117eca630>],
#  [Text(6.735557395310444e-17, 1.1, ''),
#   Text(-0.7778174593052025, -0.7778174593052023, ''),
#   Text(0.7778174593052023, -0.7778174593052025, '')])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import *  
from matplotlib.pylab import mpl
mpl.rcParams['font.size'] = 15 
custom_font = mpl.font_manager.FontProperties(fname='微软雅黑.ttf') 

years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

mpl.rcParams['font.sans-serif'] = ['SimHei'] 
plt.plot(years, gdp, color='green', marker='o',linestyle='solid');
plt.title(u'样本类别',fontproperties=custom_font) 
plt.ylabel(u'各类样本数量',fontproperties=custom_font)
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#encoding=utf-8
# %matplotlib inline
import matplotlib.pyplot as plt
 
# 121 > 1行2列第1个
fig1 = plt.subplot(121)
plt.pie([1,2,3])
# 122 > 1行2列第2个
fig2 = plt.subplot(122)
plt.title(u'抖音使用现状分析',fontproperties=custom_font)
plt.pie([10,5,5])
plt.title()
# Out:
# ---------------------------------------------------------
# AttributeError          Traceback (most recent call last)
# <ipython-input-13-0df404af1e52> in <module>
#      10 plt.title(u'抖音使用现状分析',fontproperties=custom_font)
#      11 plt.pie([10,5,5])
# ---> 12 plt.title(fig2,u'抖音使用现状分析',fontproperties=custom_font)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, **kwargs)
#    3056 def title(label, fontdict=None, loc='center', pad=None, **kwargs):
#    3057     return gca().set_title(
# -> 3058         label, fontdict=fontdict, loc=loc, pad=pad, **kwargs)
#    3059
#    3060
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, **kwargs)
#     229         title.update(default)
#     230         if fontdict is not None:
# --> 231             title.update(fontdict)
#     232         title.update(kwargs)
#     233         return title
#
# /usr/local/lib/python3.7/site-packages/matplotlib/text.py in update(self, kwargs)
#     184         # Update bbox last, as it depends on font properties.
#     185         sentinel = object()  # bbox can be None, so use another sentinel.
# --> 186         bbox = kwargs.pop("bbox", sentinel)
#     187         super().update(kwargs)
#     188         if bbox is not sentinel:
#
# AttributeError: 'str' object has no attribute 'pop'
