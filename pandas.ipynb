# %%
import pandas as pd

ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

print (df)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.groupby('Year').groups
# Out:
# {2014: Int64Index([0, 2, 4, 9], dtype='int64'),
#  2015: Int64Index([1, 3, 5, 10], dtype='int64'),
#  2016: Int64Index([6, 8], dtype='int64'),
#  2017: Int64Index([7, 11], dtype='int64')}

# %%
import pandas as pd

ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

grouped = df.groupby('Year')

for name,group in grouped:
#     print (name)
    print (group)
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
import numpy as np
print(grouped['Points'].agg(np.mean))
# Out:
# Year
# 2014    795.25
# 2015    769.50
# 2016    725.00
# 2017    739.00
# Name: Points, dtype: float64

# %%
print(grouped['Points'].agg([np.mean,np.max,np.size]))
# Out:
#         mean  amax  size
# Year
# 2014  795.25   876     4
# 2015  769.50   812     4
# 2016  725.00   756     2
# 2017  739.00   788     2

# %%
print(grouped.max())
# Out:
#         Team  Rank  Points
# Year
# 2014  Royals     4     876
# 2015   kings     4     812
# 2016  Riders     2     756
# 2017  Riders     2     788

# %%
d=df.groupby(['Year','Team']).agg(np.size)

# %%
d.count
# Out:
# <bound method DataFrame.count of              Rank  Points
# Year Team
# 2014 Devils     1       1
#      Kings      1       1
#      Riders     1       1
#      Royals     1       1
# 2015 Devils     1       1
#      Riders     1       1
#      Royals     1       1
#      kings      1       1
# 2016 Kings      1       1
#      Riders     1       1
# 2017 Kings      1       1
#      Riders     1       1>

# %%
dd=df.groupby(['Year']).agg(np.size)

# %%
dd
# Out:
#       Team  Rank  Points
# Year
# 2014     4     4       4
# 2015     4     4       4
# 2016     2     2       2
# 2017     2     2       2

# %%
dd['Team'].values[0]
# Out:
# 4

# %%
d['Rank']=d['Rank']/dd['Rank']

# %%
d
# Out:
#              Rank  Points
# Year Team
# 2014 Devils  0.25       1
#      Kings   0.25       1
#      Riders  0.25       1
#      Royals  0.25       1
# 2015 Devils  0.25       1
#      Riders  0.25       1
#      Royals  0.25       1
#      kings   0.25       1
# 2016 Kings   0.50       1
#      Riders  0.50       1
# 2017 Kings   0.50       1
#      Riders  0.50       1

# %%
d.drop('Points',axis=1,inplace=True)

# %%
dt=d.T

# %%
dt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Kings'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
data1=pd.read_csv('sex_data.csv')
data1.head()
# Out:
#    User_ID Gender   Age Location  Verification Sexual_orientation  \
# 0    10386   male  34,6        A  Non_Verified         Homosexual
# 1       14   male  32,2        J  Non_Verified       Heterosexual
# 2    16721   male  33,6        K  Non_Verified       Heterosexual
# 3    16957   male    34        H  Non_Verified       Heterosexual
# 4    17125   male  39,5        B  Non_Verified       Heterosexual
#
#   Sexual_polarity Looking_for Points_Rank      Last_login Member_since  \
# 0          Switch         Men       50.00  before_10_days    17.9.2012
# 1        Dominant       Women      518.00   before_1_days    1.11.2009
# 2        Dominant       Women      150.00   before_3_days     1.4.2013
# 3        Dominant       Women      114.00   before_4_days     8.4.2013
# 4        Dominant       Women      497.00   before_5_days    14.4.2013
#
#   Number_of_Comments_in_public_forum Time_spent_chating_H.M  \
# 0                                 32                  00:02
# ...

# %%
data.shape
# Out:
# (28831, 18)

# %%
data=data1.groupby(['Location','Gender']).agg(np.size)

# %%
data
# Out:
#                            User_ID   Age  Verification  Sexual_orientation  \
# Location           Gender
# A                  female     2375  2375          2375                2375
#                    male       8569  8569          8569                8569
# A kraj             male          2     2             2                   2
# B                  female      805   805           805                 805
#                    male       2766  2766          2766                2766
# C                  female      273   273           273                 273
#                    male        903   903           903                 903
# D                  female      116   116           116                 116
#                    male        339   339           339                 339
# E                  female      206   206           206                 206
#                    male        744   744           744                 744
# ...

# %%
dataf=data1.groupby('Location').agg(np.size)

# %%
data['Age']=data['Age']/dataf['Age']

# %%
data
# Out:
#                            User_ID       Age  Verification  \
# Location           Gender
# A                  female     2375  0.217014          2375
#                    male       8569  0.782986          8569
# A kraj             male          2  1.000000             2
# B                  female      805  0.225364           805
#                    male       2766  0.774356          2766
# C                  female      273  0.232143           273
#                    male        903  0.767857           903
# D                  female      116  0.254945           116
#                    male        339  0.745055           339
# E                  female      206  0.216614           206
#                    male        744  0.782334           744
# F                  female      196  0.238443           196
#                    male        626  0.761557           626
# G                  female      502  0.227047           502
# ...

# %%
df = pd.DataFrame({'col1': [1, 2]})

# %%
df
# Out:
#    col1
# 0     1
# 1     2

# %%
df.size
# Out:
# 2

# %%
data.size
# Out:
# 528

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=2, step=1), Index(['col1'], dtype='object')]

# %%
df.axes[1][0]
# Out:
# 'col1'

# %%
df.memory_usage()
# Out:
# Index    80
# col1     16
# dtype: int64

# %%
data526=data['Age']

# %%
data526=pd.DataFrame(data526)

# %%
idx = pd.IndexSlice
data526.loc['A','female']
# Out:
# Age    0.217014
# Name: (A, female), dtype: float64

# %%
data526.swaplevel('Location','Gender').loc['female',:].shape
# Out:
# (16, 1)

# %%
data526.swaplevel('Location','Gender').loc['male',:]
# Out:
#                          Age
# Location
# A                   0.782986
# A kraj              1.000000
# B                   0.774356
# C                   0.767857
# D                   0.745055
# E                   0.782334
# F                   0.761557
# G                   0.772953
# H                   0.753213
# J                   0.796231
# Jihomoravsk_ý kraj  1.000000
# K                   0.752688
# L                   0.768778
# M                   0.770817
# N                   0.762440
# O                   0.815022
# S                   0.795455

# %%
data526.sort_values('Age',ascending=False)
# Out:
#                                 Age
# Location           Gender
# South Moravian     female  1.000000
# A kraj             male    1.000000
# Jihomoravsk_ý kraj male    1.000000
# O                  male    0.815022
# J                  male    0.796231
# S                  male    0.795455
# A                  male    0.782986
# E                  male    0.782334
# B                  male    0.774356
# G                  male    0.772953
# M                  male    0.770817
# L                  male    0.768778
# C                  male    0.767857
# N                  male    0.762440
# F                  male    0.761557
# H                  male    0.753213
# K                  male    0.752688
# D                  male    0.745055
#                    female  0.254945
# K                  female  0.247312
# H                  female  0.246787
# F                  female  0.238443
# N                  female  0.237560
# C                  female  0.232143
# ...

# %%
df1=pd.DataFrame(np.arange(12).reshape(4,3),index=[list("AABB"),[1,2,1,2]],columns=[list("XXY"),[10,11,10]])
df1
# Out:
#      X       Y
#     10  11  10
# A 1  0   1   2
#   2  3   4   5
# B 1  6   7   8
#   2  9  10  11

# %%
df1.columns.names=['XY','sum']
df1.index.names=['AB','num']
df1
# Out:
# XY      X       Y
# sum    10  11  10
# AB num
# A  1    0   1   2
#    2    3   4   5
# B  1    6   7   8
#    2    9  10  11

# %%
df1.swaplevel('XY','sum')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_number(self, level)
#     765                                  'level number' % level)
# --> 766             level = self.names.index(level)
#     767         except ValueError:
#
# ValueError: 'XY' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-227-bae076b36a66> in <module>
# ----> 1 df1.swaplevel('XY','sum')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in swaplevel(self, i, j, axis)
#    4686         axis = self._get_axis_number(axis)
#    4687         if axis == 0:
# -> 4688             result.index = result.index.swaplevel(i, j)
#    4689         else:
# ...
